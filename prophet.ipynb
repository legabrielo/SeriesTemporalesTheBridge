# %% [markdown]
# # Utilización de Prophet para mejorar el proyecto

# %%
#Para la manipulación de datos
import pandas as pd
import time
import numpy as np

# Para el análsis de la muestra 
import matplotlib.pyplot as plt 
import seaborn as sns 

# Para analizar la serie de tiempo 
import prophet

# %%
# LEEMOS EL DATASET, SE PARSEA LA COLUMNA 'DIA' 
df = pd.read_excel('Bici1.xlsx', index_col='DIA', parse_dates=['DIA'])
df.head()
# Out:
#              Año  Mes  Usos bicis abono anual día  \
# DIA
# 2014-06-23  2014    6                        20.0
# 2014-06-24  2014    6                        24.0
# 2014-06-25  2014    6                       105.0
# 2014-06-26  2014    6                       120.0
# 2014-06-27  2014    6                       131.0
#
#             Usos bicis abono ocasional día  Usos bicis total día  Unnamed: 6  \
# DIA
# 2014-06-23                            79.0                  99.0         NaN
# 2014-06-24                            48.0                  72.0         NaN
# 2014-06-25                            14.0                 119.0         NaN
# 2014-06-26                            15.0                 135.0         NaN
# 2014-06-27                            18.0                 149.0         NaN
#
#             Usos bicis abono anual acumulado mes  \
# DIA
# 2014-06-23                                  20.0
# 2014-06-24                                  44.0
# 2014-06-25                                 149.0
# 2014-06-26                                 269.0
# 2014-06-27                                 400.0
#
#             Usos bicis abono ocasional acumulado mes  \
# DIA
# 2014-06-23                                      79.0
# 2014-06-24                                     127.0
# 2014-06-25                                     141.0
# 2014-06-26                                     156.0
# 2014-06-27                                     174.0
#
#             Usos bicis total acumulado mes  Unnamed: 10  ...  \
# DIA                                                      ...
# 2014-06-23                            99.0          NaN  ...
# 2014-06-24                           171.0          NaN  ...
# 2014-06-25                           290.0          NaN  ...
# 2014-06-26                           425.0          NaN  ...
# 2014-06-27                           574.0          NaN  ...
#
#             Usos bicis abono ocasional acumulado año  \
# DIA
# 2014-06-23                                      79.0
# 2014-06-24                                     127.0
# 2014-06-25                                     141.0
# 2014-06-26                                     156.0
# 2014-06-27                                     174.0
#
#             Usos bicis total acumulado año  Unnamed: 14  \
# DIA
# 2014-06-23                            99.0          NaN
# 2014-06-24                           171.0          NaN
# 2014-06-25                           290.0          NaN
# 2014-06-26                           425.0          NaN
# 2014-06-27                           574.0          NaN
#
#             Usos abono anual acumulado  Usos abono ocasional acumulado  \
# DIA
# 2014-06-23                        20.0                            79.0
# 2014-06-24                        44.0                           127.0
# 2014-06-25                       149.0                           141.0
# 2014-06-26                       269.0                           156.0
# 2014-06-27                       400.0                           174.0
#
#             Usos total acumulado desde inicio  Unnamed: 18  \
# DIA
# 2014-06-23                               99.0          NaN
# 2014-06-24                              171.0          NaN
# 2014-06-25                              290.0          NaN
# 2014-06-26                              425.0          NaN
# 2014-06-27                              574.0          NaN
#
#             Acumulado mes total  Unnamed: 20  Unnamed: 21
# DIA
# 2014-06-23                  NaN          NaN          NaN
# 2014-06-24                  NaN          NaN          NaN
# 2014-06-25                  NaN          NaN          NaN
# 2014-06-26                  NaN          NaN          NaN
# 2014-06-27                  NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
# Hacemos la limpia de datos
df.drop("Unnamed: 6", axis=1)
df = df.drop(df.index[3053::])
df = df.drop(columns= ['Usos bicis total día', 'Unnamed: 6',
       'Usos bicis abono anual acumulado mes',
       'Usos bicis abono ocasional acumulado mes',
       'Usos bicis total acumulado mes', 'Unnamed: 10',
       'Usos bicis abono anual acumulado año',
       'Usos bicis abono ocasional acumulado año',
       'Usos bicis total acumulado año', 'Unnamed: 14',
       'Usos abono anual acumulado', 'Usos abono ocasional acumulado',
       'Usos total acumulado desde inicio', 'Unnamed: 18',
       'Acumulado mes total', 'Unnamed: 20', 'Unnamed: 21'], axis=1)
df = df.drop(df.index[3053::])
df = df.drop('Mes', axis=1)
df = df.drop('Año', axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19368\391688174.py in <module>
#       1 # Hacemos la limpia de datos
# ----> 2 df.drop("Unnamed: 6", axis=1)
#       3 df = df.drop(df.index[3053::])
#       4 df = df.drop(columns= ['Usos bicis total día', 'Unnamed: 6',
#       5        'Usos bicis abono anual acumulado mes',
#
# c:\Users\Gabriel Castillo\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Gabriel Castillo\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# c:\Users\Gabriel Castillo\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# c:\Users\Gabriel Castillo\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# c:\Users\Gabriel Castillo\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Unnamed: 6'] not found in axis"
